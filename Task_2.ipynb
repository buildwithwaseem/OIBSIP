# %% [markdown]
# <a href="https://colab.research.google.com/github/buildwithwaseem/OIBSIP/blob/main/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")

# %%
df = pd.read_csv("Unemployment in India.csv")
df.head()

# %%
df.info()

# %% [markdown]
# ## Data Cleaning

# %%
df = df.dropna()

# %%
df.columns = df.columns.str.strip()
df.columns

# %%
df.isnull().sum()

# %%
df = df.dropna()
df.shape

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.head()

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['Estimated Unemployment Rate (%)'], color='red')
plt.title("Unemployment Rate Over Time in India")
plt.xlabel("Date")
plt.ylabel("Unemployment Rate (%)")
plt.show()

# %%
region_unemployment = df.groupby('Region')['Estimated Unemployment Rate (%)'].mean().sort_values()

plt.figure(figsize=(10,6))
region_unemployment.plot(kind='barh', color='orange')
plt.title("Average Unemployment Rate by Region")
plt.xlabel("Unemployment Rate (%)")
plt.ylabel("Region")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Area', y='Estimated Unemployment Rate (%)', data=df)
plt.title("Unemployment Rate: Urban vs Rural")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.select_dtypes(include=np.number).corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
